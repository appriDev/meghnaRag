# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="hello abdul how are you? where are you going?",
    metadata={
        "source":"shobai_geche_bone.pdf",
        "author":"Baten Mia",
        "pages":1,
    }
)

doc
# Out:
# Document(metadata={'source': 'shobai_geche_bone.pdf', 'author': 'Baten Mia', 'pages': 1}, page_content='hello abdul how are you? where are you going?')

# %%
#create a sample  text 
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts = {
    "../data/text_files/ezio.txt": '''Born in Florence, 1459, to the noble Auditore family.
    Witnessed the execution of his father and brothers, sparking his quest for revenge.
    Trained by his uncle Mario at Villa Auditore in Monteriggioni.
    Mastered the Hidden Blade, parkour, and social stealth.
    Defeated the Pazzi conspirators and eventually the Grand Master, Rodrigo Borgia.
    Rebuilt the Assassin Brotherhood in Rome to dismantle the Borgia influence.
    Travelled to Masyaf and Constantinople to uncover the secrets of Altaïr Ibn-La'Ahad.
    Retired to a peaceful life in the Tuscan countryside with Sofia Sartor.
    Died in Florence in 1524, leaving behind a legacy of freedom and wisdom.''',

    "../data/text_files/batman.txt": '''Witnessed the tragic murder of his parents, Thomas and Martha Wayne, in a Gotham City alley.
    Travelled the world for years to master martial arts, detective skills, and forensic science.
    Adopted the persona of the Batman to strike fear into the hearts of criminals.
    Operates out of the Batcave beneath Wayne Manor with the help of Alfred Pennyworth.
    Utilizes high-tech gadgets, the Batmobile, and a strict code against killing.
    Serves as the founding member of the Justice League and the protector of Gotham.''',

    "../data/text_files/vaas.txt": '''The unpredictable and psychotic leader of the pirates on Rook Islands.
    Known for his iconic "Definition of Insanity" monologue to protagonist Jason Brody.
    Formerly a member of the Rakyat tribe before being corrupted by power and drugs.
    Works under the slave trader Hoyt Volker while terrorizing the local population.
    Defined by his intense emotional instability and philosophical view of chaos.
    Remains one of the most charismatic and feared villains in the Far Cry series.'''
}

# %%
for path,context in sample_texts.items():
    with open(path, 'w', encoding="utf-8") as f:
        f.write(context)

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("../data/text_files/ezio.txt", encoding="utf-8")
document = loader.load()

# %%
document
# Out:
# [Document(metadata={'source': '../data/text_files/ezio.txt'}, page_content="Born in Florence, 1459, to the noble Auditore family.\n    Witnessed the execution of his father and brothers, sparking his quest for revenge.\n    Trained by his uncle Mario at Villa Auditore in Monteriggioni.\n    Mastered the Hidden Blade, parkour, and social stealth.\n    Defeated the Pazzi conspirators and eventually the Grand Master, Rodrigo Borgia.\n    Rebuilt the Assassin Brotherhood in Rome to dismantle the Borgia influence.\n    Travelled to Masyaf and Constantinople to uncover the secrets of Altaïr Ibn-La'Ahad.\n    Retired to a peaceful life in the Tuscan countryside with Sofia Sartor.\n    Died in Florence in 1524, leaving behind a legacy of freedom and wisdom.")]

# %%
from langchain_community.document_loaders import DirectoryLoader

dir_loader=DirectoryLoader(
    '../data/pdfs',
    glob="**/*",
    loader_cls=TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=False
)

# %%
documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/text_files/vaas.txt'}, page_content='The unpredictable and psychotic leader of the pirates on Rook Islands.\n    Known for his iconic "Definition of Insanity" monologue to protagonist Jason Brody.\n    Formerly a member of the Rakyat tribe before being corrupted by power and drugs.\n    Works under the slave trader Hoyt Volker while terrorizing the local population.\n    Defined by his intense emotional instability and philosophical view of chaos.\n    Remains one of the most charismatic and feared villains in the Far Cry series.'),
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

pdf_dir_loader=DirectoryLoader(
    '../data/pdfs',
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=False
)

pdf_documents = pdf_dir_loader.load()

pdf_documents
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-03-31T04:10:17+00:00', 'source': '../data/pdfs/vaas.pdf', 'file_path': '../data/pdfs/vaas.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-03-31T04:10:17+00:00', 'trapped': '', 'modDate': "D:20260331041017+00'00'", 'creationDate': "D:20260331041017+00'00'", 'page': 0}, page_content='The unpredictable and psychotic leader of the pirates on Rook Islands.\nKnown for his iconic "Definition of Insanity" monologue to protagonist Jason Brody.\nFormerly a member of the Rakyat tribe before being corrupted by power and drugs.\nWorks under the slave trader Hoyt Volker while terrorizing the local population.\nDefined by his intense emotional instability and philosophical view of chaos.\nRemains one of the most charismatic and feared villains in the Far Cry series.'),
# ...
